# %% [markdown]
# ## Restauración de base de datos en SQL Server

# %% [markdown]
# - Para este ejemplo se va a descargar los siguientes archivos:
# https://learn.microsoft.com/en-us/sql/samples/adventureworks-install-configure?view=sql-server-ver16&tabs=ssms
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Primero te debes poner en el archivo de database
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Una vez que distes a la opción restaurar base de datos te aparecera una ventana, seleccionar donde se encuentra.
#
# ![image.png](attachment:image.png)
