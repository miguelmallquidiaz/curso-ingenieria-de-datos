# %% [markdown]
# ## Lenguaje de definición de datos (DDL)

# %% [markdown]
# - Se usa para crear, modificar o eliminar estructuras (tablas, bases, vistas).
# - Se veran temás como **CREATE TABLE**, **ALTER TABLE**, **TRUNCATE TABLE**, **DROP TABLE**

# %% [markdown]
# ### CREATE TABLE
#
# El comando `CREATE TABLE` se utiliza para crear una nueva tabla en una base de datos y definir su estructura (campos y tipos de datos) antes de almacenar información en ella.
#
# **Sintaxis básica:**
#
# ```sql
# CREATE TABLE table_name (
#     column_1 datatype,
#     column_2 datatype,
#     ...
# );

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ALTER TABLE
#
# El comando `ALTER TABLE` se utiliza para modificar la estructura de una tabla existente. Esto incluye agregar, eliminar o modificar columnas, cambiar el tipo de dato a otro.
#
# - `ADD`: Se utiliza para añadir una nueva columna.
# - `ALTER COLUMN`: Modificar el tipo de dato de una columna en especifico.
# - `DROP COLUMN`: Se utiliza para eliminar una columna existente de la tabla.
#
# **Sintaxis básica:**
#
# ```sql
# ALTER TABLE table_name
# ADD column_name datatype;
#
# ALTER TABLE table_name
# ALTER COLUMN column_name datatype;
#
# ALTER TABLE table_name
# DROP COLUMN column_name;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TRUNCATE TABLE
#
# El comando `TRUNCATE TABLE` elimina de manera rápida todos los registros de la tabla, pero mantiene la estructura de esta.
#
# **Sintaxis básica:**
#
# ```sql
# TRUNCATE TABLE table_name;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DROP TABLE
#
# El comando `DROP TABLE` elimina  por completo la tabla.
#
# **Sintaxis básica:**
#
# ```sql
# DROP TABLE table_name;

# %% [markdown]
# ![image.png](attachment:image.png)
